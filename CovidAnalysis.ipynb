# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"D:\Pooja Personal\DataScience\covid_19_india.csv")

# %%
data.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed'],
#       dtype='object')

# %%
data.tail()
# Out:
#        Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 522  17959  2021-08-07  8:00 AM            Rajasthan                       -
# 523  17995  2021-08-08  8:00 AM            Rajasthan                       -
# 524  18031  2021-08-09  8:00 AM            Rajasthan                       -
# 525  18067  2021-08-10  8:00 AM            Rajasthan                       -
# 526  18103  2021-08-11  8:00 AM            Rajasthan                       -
#
#     ConfirmedForeignNational   Cured  Deaths  Confirmed
# 522                        -  944606    8954     953793
# 523                        -  944621    8954     953812
# 524                        -  944636    8954     953827
# 525                        -  944670    8954     953840
# 526                        -  944700    8954     953851

# %%
data.describe()
# Out:
#                 Sno          Cured       Deaths      Confirmed
# count    527.000000     527.000000   527.000000     527.000000
# mean    8723.643264  285307.058824  2795.235294  308101.814042
# std     5374.706353  312030.601741  2898.499202  326680.539849
# min       37.000000       0.000000     0.000000       1.000000
# 25%     4045.000000   17986.000000   506.500000   24070.000000
# 50%     8654.000000  214616.000000  2130.000000  237669.000000
# 75%    13369.000000  321891.000000  2820.000000  333824.000000
# max    18103.000000  944700.000000  8954.000000  953851.000000

# %%
data.isnull().sum()
# Out:
# Sno                         0
# Date                        0
# Time                        0
# State/UnionTerritory        0
# ConfirmedIndianNational     0
# ConfirmedForeignNational    0
# Cured                       0
# Deaths                      0
# Confirmed                   0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed'],
#       dtype='object')

# %% [markdown]
# # Relating the variables with scatterplots

# %%
sns.relplot(x="State/UnionTerritory" ,y="Deaths" , hue = "Cured" ,data=data)

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed'],
#       dtype='object')

# %%
sns.relplot(x="State/UnionTerritory" , y ="Deaths" ,kind = "line" , data=data)

# %%
data.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed'],
#       dtype='object')

# %%
sns.catplot(x ="State/UnionTerritory" , y = "Cured" ,data=data)
